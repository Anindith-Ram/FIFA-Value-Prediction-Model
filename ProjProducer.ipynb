# %% [markdown]
# Among the available players in the Male 2022 player dataset, identify which player is
# most popular in YouTube video comments. (Use a 5-minute YouTube feed to pull videos).
# o Collect recent YouTube videos related to the topic by using the search keywords
# [fifa world cup, soccer, football, fifa] and analyze their comments for relevance.
# o Use a publisher/subscriber model to address this requirement: the publisher
# should publish all comments, while the subscriber processes and analyzes them.
# o Provide a dump of your YouTube feed comments to justify your answer.
# (Depending on the time you are pulling the data, you may get no answer).
# o Provide a screenshot of the output you are getting in the terminal.

# %%
import socket
from confluent_kafka import Producer
import time
from datetime import datetime, timedelta
import json
from googleapiclient.discovery import build

# API Reference website
# https://developers.google.com/youtube/v3/docs/

BROKER = 'localhost:9092'
TOPIC = 'youtube_topic'

# api key referenced above



youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)
keywords = ['champions league', 'premier league', 'series a', 'la liga', 'bundesliga', 'ligue 1', 'mls', 'soccer', 'world cup']

def search_videos(keyword):
    request = youtube.search().list(
        part='snippet',
        q=keyword,
        type='video',
        order='date',
        maxResults=5
    )
    response = request.execute()
    videos = []
    for item in response['items']:
        videos.append(item['id']['videoId'])
    return videos

def get_comments(video_id):
    # set maxResults to 50 to slow down api usage
    request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        textFormat='plainText',
        order='relevance',
        maxResults=50
    )
    response = request.execute()
    comments = []
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append({
            'author': comment['authorDisplayName'],
            'text': comment['textDisplay'],
            'like_count': comment['likeCount'],
            'published_at': comment['publishedAt'],
            'video_id': video_id
        })
    return comments

def create_kafka_producer(broker):
    conf = {
        'bootstrap.servers': broker,
        'client.id': socket.gethostname()
    }
    return Producer(conf)

video_ids = []
for keyword in keywords:
    vids = search_videos(keyword)
    video_ids.extend(vids)

# ensure no duplicate video ids
video_ids = list(set(video_ids))
producer = create_kafka_producer(BROKER)
seen_comments = set()

# 5 minute timer
start_time = datetime.now()
end_time = start_time + timedelta(minutes=5)
while datetime.now() < end_time:
    for video_id in video_ids:
        if datetime.now() >= end_time:
            break
        # error handling when comments are disabled for the video
        try:
            comments = get_comments(video_id)
        except:
            continue
        if not comments:
            continue
        for comment in comments:
            comment_id = comment['published_at'] + comment['author'] + comment['video_id']
            # ensure no duplicate comments
            if comment_id not in seen_comments:
                seen_comments.add(comment_id)
                comment_data = {
                    'author': comment['author'],
                    'text': comment['text'],
                    'like_count': comment['like_count'],
                    'published_at': comment['published_at'],
                    'video_id': comment['video_id']
                }
                key_str = f"{comment['author']}: {comment['text']}"
                value_str = json.dumps(comment_data)
                producer.produce(TOPIC, key=key_str.encode('utf-8'), value=value_str.encode('utf-8'))
                print(f"Sent: {comment['author']} - {comment['text'][:50]}")
        producer.flush()
    if datetime.now() < end_time:
        time.sleep(30)

producer.flush()
# Out:
# Sent: @andrewgleeson8862 - Not as if the england team have hard teams to beat
# Sent: @johnjonathan1257 - IS ROY KEANE WEARING HIS SMOKING JACKET TONIGHT ,W
# Sent: @josemanuelmartineztortosa7848 - Se gano la señora colegiada, un sobresueldo  en un
# Sent: @URKG - As a Portugal and CR7 fan, this one hurts.
#
# Watch
# Sent: @JB2tekky - This was Cristiano's last world cup qualifying gam
# Sent: @captainfalconmain6576 - Penaldo not even top 5 players of all time
# Sent: @Malik69363 - A torcida da ponte preta é assim
# Sent: @rafaelolaguezjr6445 - No way.
# Sent: @DilekKaya-hd4zq - Omg wow😂
# Sent: @MLSMoves - Video starts at 1:18
# Sent: @rokatrevo - LETS GOOOOO
# Sent: @Goatmessi3508 - Very exciting ❤
# Sent: @MLSFanUSA - Huge MLS W
# Sent: @michaelpeli2429 - The 2027 summer transfer window should be HUGE for
# Sent: @michaelpeli2429 - Sometimes, MLS accidentally gets something right.
# Sent: @Jasinho10 - Real excited! Between this and AppleTV removing th
# Sent: @iliyasesoof17 - I feel like we get the best of both worlds here. I
# Sent: @josecandelario7614 - Any confirmation on the winter “break” actually be
# Sent: @michaelpeli2429 - The winter break would miss the entire NFL and col
# Sent: @Wingcake1 - I knew you would make a video even spanish soccer
# Sent: @ElondonOSRS - Great move
# Sent: @richsmith6997 - The past 15 years have been fun. But I live in a n
# Sent: @AfricanBoy-et5iz - As a Real Madrid fan. I felt sorry for Liverpool a
# Sent: @JohnnyMac95 - For anyone curious:
#
# 1. de Gea (415)
# 2. Fàbregas (
# Sent: @CalvinOghenekaroObriki - Ball knowledge 0
# Sent: @ShaneDarnell-b4l - My guy loves Google
# Sent: @geo.dav.17 - I was almost sure for rodri 😮😮😮
# Sent: @kieran8413 - thinking rodri has more than Torres. Wow
# Sent: @wanderingnomads929 - Azpiliqueta? Traore? 🪦🥀
# Sent: @TPDS0109 - Didn't the guy on the left have a Newcastle shirt
# Sent: @ThomasMouse-d5b - ARTETA
# CAZORLA
# AZPILICUETA
# DIEGO COSTA
# Sent: @SamSlammer9333 - Arteta
# Sent: @Shortznclipzyt - Carzola
# Sent: @ChrisLPK - Abysmal ball knowledge get your ish together
# Sent: @Spartan_Ace - Azli bro
# Sent: @Len_chill-guy - First
# Sent: @itsIzagi - Alors d'accord avec le coach ??
# Sent: @ChicagoFireFCAnimatons97 - Remember when we watched real MLS in our local are
# Sent: @Jack-u6n5v - So ur saying I wasted my money for 3 seasons?
# Sent: @OLEKSIIALEXEY - Если бы в случае проиграша сборной УКРАИНЫ,  все р
# Sent: @MolcasFutbol - ¿Quién se hará aficionado del Rayo a partir de hoy
# Sent: @hungrycoyote86 - Que viva el Rayito! Un siglo representando a un ba
# Sent: @jonorcasitas5275 - Que pesado eres! De verdad, descansa un poco! Hoy
# Sent: @awol_evan - Cold climate teams are just gonna get most of thei
# Sent: @gilbertosergiooliveira3770 - Ter visto Romário jogar e ver os atacantes de hoje
# Sent: @eddimartin1981 - Essa adiantada de bola do Romário era na medida
# Sent: @RB420.00 - Pra ele era fácil, por isso.. kkkk
# Sent: @gamer.noob33 - Se fosse hoje em dia, seria gol anulado e cartão p
# Sent: @RenanBigfoot - Pra ele era fácil Bro kkkkk e não que ele fazia pa
# Sent: @MultiversosdoPedro - Parece que o unico time da europa que da importânc
# Sent: @pauloaraujo1161 - Eles têm o melhor campeonato. Mas isso se deve ao
# Sent: @rockcanine8658 - Eles não ligam por causa do Eurocentrismo, eles vi
# Sent: @davireboucasdelima1665 - Inglaterra clubes: 👾
# Seleção: 🐔
# Sent: @aninhasacana69 - Isso é nítido, inclusive vai ser o único título qu
# Sent: @lucasfriedrich2066 - Sempre disse que a copa do mundo de clubes era uma
# Sent: @joaovitorfernandes3554 - Eles tratam com desdém para sempre ter a condição
# Sent: @churrasqueirobugado4037 - Pior que é verdade. Os ingleses só acompanham outr
# Sent: @1giro_fut - Simplesmente o choque de cultura na prática. Loucu
# Sent: @VictorMacedo_ - Rapaz, foda-se se eles gostam ou não. Eu gostei, n
# Sent: @JohnAnt - Seria mais ou menos a relação do Brasil com a libe
# Sent: @Semnome-jg6oj - É fato, Libertadores>>>Brasileirão>>Copa do Brasil
# Sent: @masterzim4718 - *Os clubes Brasileiros tem chance de ganhar alguma
# Sent: @JoaoVitor-qw3zz - Isso acontece igual nos Estados Unidos, sempre val
# Sent: @VidaRealEdits - Cara, evidentemente eles tem mais soberba que nois
# Sent: @masksniper157 - Para nós brasileiros o Mundial de clubes é mil mar
# Sent: @LuffyzinSecundario - A diferença é que a Premier League é só na Inglate
# Sent: @ArthurGuedesTG - A PL hoje vive o que o Brasileirão vivia antigamen
# Sent: @rusticbeet - As pessoas vão criticar os ingleses mais a gente f
# Sent: @vulgo_etvaldomandrakudo3208 - A realidade é que brasileiro goza muito com o dos
# Sent: @gabriellucas4544 - Eles só tem uma copa e se acham de mais
# Sent: @davireboucasdelima1665 - Então se não ligam custava deixar o Flamengo ganha
# Sent: @AlienXPrime - Engraçado é que eles geralmente são amassados nas
# Sent: @Snow-Xz1 - Fodase?sério que alguém liga pra isso? O brasileir
# Sent: @roneyooliveira - E daí que os caras não ligam, a gente gosta e da i
# Sent: @CleyssonthiagoMarquesfernandes - Me nota, há meses eu assisto todos os seus vídeos
# Sent: @pedrosaulguilhermino8193 - Mais os ingleses tem isso msm,essa soberba,ate os
# Sent: @Pedro____5555 - Melhor campeonato do mundo pq é o que tem mais din
# Sent: @Oprotagonista17 - Mundial pra eles não e nada devido ao investimento
# Sent: @RD7RUBRONEGRO - Os europeus se acha demais, eles fala isso pra ger
# Sent: @CleyssonthiagoMarquesfernandes - Me nota, eu gosto muito dos seus vídeos e assisto
# Sent: @EnzoTeixeira. - Salve
# Sent: @pedrorodrigues-z4q5i - Adoro vc
# Sent: @Mauricio.f2550 - Esse gatinho 🐈‍⬛ ganha um aninho a cada like 😊
# Sent: @CaioMiguelPereiradoNascimento - Os caras criaram o futebol
# Sent: @dayvisonmoreiradelima4021 - Foda se a Inglaterra...😂
# Sent: @l4ion-b9v - Ingleses são Enzos
# Sent: @gabrielvieira4796 - E brasileiro paga pau pra inglês e americano 😂
# Sent: @krat0s9666 - É a única explicação para Flamengo ganhar do Chels
# Sent: @Jozao_Colorado_Mercedista - Florida cap de luxo
# Sent: @pedrorodrigues-z4q5i - Me responde
# Sent: @HaviGregore - A seleção lixo não ganha nada desde 1966 kkkk palh
# Sent: @Vinícius_1941 - E ainda tinha bostileiro falando que os europeus e
# Sent: @CleyssonthiagoMarquesfernandes - Primeiro.
# Sent: @pedrorodrigues-z4q5i - Segundo
# Sent: @MegaPiroqueiro - Eles falam que não se importam com o mundial pra t
# Sent: @MegaPiroqueiro - Os ingleses só se importam com a Premier league, p
# Sent: @dietmarcousain768 - Auf geht's 😊
# Sent: @ЕленаЕленаСолодСолод - VALENCIA не хватает скорости в своих действиях .
# Sent: @adamk1112 - Never pay for subscriptions, go ahead and get your
# Sent: @posterchiild - This is great news! Time to really compete at the
# Sent: @AbdulGaniuKunfayakuun-c3u - My term has won again ❤❤❤❤😂😊
# 0
